# %%
from bs4 import BeautifulSoup
from itertools import chain
from collections import Counter
from nltk.corpus import stopwords
import urllib
from lxml import html
import numpy as np
import requests
import pandas as pd
import nltk
from nltk import corpus
from nltk.stem.porter import PorterStemmer
from matplotlib import pyplot as plt
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
import requests_cache
requests_cache.install_cache('demo_cache')
import math

# %%
import requests

link = "http://www.pythonforbeginners.com/beautifulsoup/beautifulsoup-4-python"
f = requests.get(link)
tree = html.fromstring(f.content)
#print f.text
tree
# Out:
# <Element html at 0xdc20d68>

# %%
##start here

# %%
import urllib2
import html2text
#import BeautifulSoup

#soup = BeautifulSoup(urllib2.urlopen('http://www.century21.com/real-estate-blog/neighborhood-checklist/').read())
#soup
#txt = soup.find('div', {'class' : 'body'})

#print html2text.html2text(txt)

# %%
import urllib2
import re

#connect to a URL
website = urllib2.urlopen('http://www.century21.com/real-estate-blog/category/buyer-advice/')

#read html code
html = website.read()

#use re.findall to get all the links
links = re.findall('"(https?://www.century21.com/real-estate-blog/.*?)"', html)
links = links[16:66]
#print links
len(links)
# Out:
# 50

# %%
#append all body contents together
b = []
paragraphs = []
for link in links:
    url = link
    r = requests.get(url)
    soup = BeautifulSoup(r.content,'lxml')
    a = soup.find_all('p')
    
    b.append(a)
# Out:
# list

# %%
#tokenize sentences
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()
a = str(b)
e = tknzr.tokenize(a)

# %%
#find the word frequency
wordfreq = [e.count(p) for p in e]
dictionary = dict(zip(e,wordfreq))
aux = [(dictionary[key], key) for key in dictionary]
aux.sort()
aux.reverse()
for j in aux: 
    print j
# Out:
# (876, u'.')
# (830, u',')
# (565, u'\\')
# (546, u'the')
# (419, u'you')
# (391, u'</p>')
# (378, u'and')
# (344, u'to')
# (340, u'<p>')
# (326, u'a')
# (281, u'your')
# (248, u'21')
# (234, u'of')
# (198, u'home')
# (185, u'"')
# (149, u'is')
# (148, u'CENTURY')
# (129, u'Real')
# (128, u'Estate')
# (123, u'n')
# (114, u'in')
# (113, u'can')
# (109, u'xae')
# (105, u'are')
# (105, u'an')
# (102, u'sales')
# (101, u'new')
# (100, u'for')
# (100, u'LLC')
# (100, u'Century')
# (100, u'=')
# (88, u'or')
# (85, u'may')
# (84, u'that')
# (83, u'>')
# (83, u'<')
# (78, u'be')
# (76, u'experienced')
# (75, u'associate')
# (70, u'have')
# (67, u'u2019s')
# (67, u'help')
# (64, u'open')
# (60, u'u2019t')
# (60, u'<br/>')
# (59, u'it')
# (58, u'more')
# (56, u'<b>')
# (56, u'</b>')
# (55, u'door')
# (54, u'about')
# (53, u'with')
# (53, u'on')
# (52, u'SMARTER')
# (52, u'FASTER')
# (52, u'BOLDER')
# (51, u'professional')
# (51, u'p')
# (51, u'not')
# (51, u'near')
# (51, u'but')
# (51, u']')
# (51, u'[')
# (50, u'}')
# (50, u'{')
# (50, u'business')
# (50, u'Find')
# (50, u'Act')
# (49, u'will')
# (49, u':')
# (43, u'by')
# (42, u'house')
# (42, u'as')
# (42, u'The')
# (41, u'u2013')
# (40, u'neighborhood')
# (38, u'how')
# (38, u'from')
# (36, u'u2019re')
# (36, u'You')
# (35, u'make')
# (34, u'so')
# (34, u'!')
# (33, u'information')
# (32, u'whether')
# (31, u'who')
# (31, u'real')
# (31, u'if')
# (31, u'estate')
# (30, u'?')
# (29, u'With')
# (28, u'they')
# (28, u'href')
# (28, u'Learn')
# (28, u'</a>')
# (27, u'presence')
# (27, u'local')
# (27, u'class')
# (27, u'System')
# (26, u'these')
# (26, u'reach')
# (26, u'global')
# (26, u'build')
# (26, u'brand')
# (26, u'Listing')
# (26, u'All')
# (25, u'xa92017')
# (25, u'them')
# (25, u'supports')
# (25, u'support')
# (25, u'service')
# (25, u'rights')
# (25, u'reserved')
# (25, u'reliable')
# (25, u'registered')
# (25, u'principles')
# (25, u'plus')
# (25, u'owned')
# (25, u'outs')
# (25, u'out')
# (25, u'marks')
# (25, u'knows')
# (25, u'ins')
# (25, u'id')
# (25, u'guaranteed')
# (25, u'fully')
# (25, u'footer-additional-disclaimer')
# (25, u'deemed')
# (25, u'copyright-text')
# (25, u'career')
# (25, u'becoming')
# (25, u'advantage')
# (25, u'accurate')
# (25, u'See')
# (25, u'Owned')
# (25, u'Opportunity')
# (25, u'Operated')
# (25, u'Office')
# (25, u'Logo')
# (25, u'Independently')
# (25, u'Housing')
# (25, u'Franchisee')
# (25, u'Fair')
# (25, u'Equal')
# (25, u'Each')
# (25, u'ADDITIONAL_DISCLAIMER')
# (25, u'<span>')
# (25, u'</span>')
# (24, u'what')
# (24, u'like')
# (24, u'buying')
# (23, u'there')
# (22, u'If')
# (21, u'up')
# (21, u'time')
# (21, u'this')
# (21, u'sure')
# (21, u'should')
# (20, u'pool')
# (20, u'look')
# (19, u'want')
# (19, u'u2019ve')
# (19, u'their')
# (19, u'potential')
# (19, u'at')
# (19, u'all')
# (18, u'when')
# (18, u'might')
# (18, u'before')
# (17, u'xa0')
# (17, u'some')
# (17, u'don')
# (17, u'It')
# (16, u'things')
# (16, u'one')
# (16, u'buyers')
# (16, u'<strong>')
# (16, u'</strong>')
# (15, u'u2014')
# (15, u'questions')
# (15, u'other')
# (15, u'need')
# (15, u'know')
# (15, u'kitchen')
# (15, u'important')
# (15, u'family')
# (15, u'any')
# (14, u'take')
# (14, u'space')
# (14, u'find')
# (14, u'Don')
# (13, u'water')
# (13, u'see')
# (13, u'process')
# (13, u'just')
# (13, u'get')
# (13, u'everything')
# (12, u'way')
# (12, u'most')
# (12, u'buyer')
# (12, u')')
# (12, u'(')
# (11, u'we')
# (11, u'u2019ll')
# (11, u'than')
# (11, u'move')
# (11, u'items')
# (11, u'into')
# (11, u'do')
# (11, u'buy')
# (11, u'A')
# (10, u'which')
# (10, u'through')
# (10, u'right')
# (10, u'good')
# (10, u'first')
# (10, u'during')
# (10, u'Your')
# (10, u'This')
# (9, u'would')
# (9, u'u201d')
# (9, u'too')
# (9, u'team')
# (9, u'such')
# (9, u'perfect')
# (9, u'people')
# (9, u'month')
# (9, u'homes')
# (9, u'feel')
# (9, u'even')
# (9, u'around')
# (9, u'agent')
# (9, u'When')
# (9, u'There')
# (9, u'Keep')
# (8, u'while')
# (8, u'stay')
# (8, u'small')
# (8, u'same')
# (8, u'our')
# (8, u'much')
# (8, u'mistakes')
# (8, u'lot')
# (8, u'list')
# (8, u'homeowners')
# (8, u'easy')
# (8, u'come')
# (8, u'big')
# (8, u'We')
# (8, u'An')
# (7, u'think')
# (7, u'step')
# (7, u'start')
# (7, u'seller')
# (7, u'room')
# (7, u'ready')
# (7, u'own')
# (7, u'living')
# (7, u'likely')
# (7, u'level')
# (7, u'last')
# (7, u'houses')
# (7, u'homeowner')
# (7, u'getting')
# (7, u'future')
# (7, u'fit')
# (7, u'different')
# (7, u'day')
# (7, u'comes')
# (7, u'better')
# (7, u'best')
# (7, u'away')
# (7, u'ask')
# (7, u'also')
# (7, u'While')
# (7, u'They')
# (7, u'<sup>')
# (7, u'</sup>')
# (6, u'work')
# (6, u'where')
# (6, u'was')
# (6, u'those')
# (6, u'swimming')
# (6, u'single')
# (6, u'remember')
# (6, u'puppy')
# (6, u'over')
# (6, u'only')
# (6, u'once')
# (6, u'needs')
# (6, u'maintenance')
# (6, u'looking')
# (6, u'long')
# (6, u'isn')
# (6, u'has')
# (6, u'filter')
# (6, u'features')
# (6, u'driveway')
# (6, u'decide')
# (6, u'appliances')
# (6, u'anything')
# (6, u'Home')
# (6, u'<i>')
# (6, u'</i>')
# (5, u'without')
# (5, u'two')
# (5, u'something')
# (5, u'share')
# (5, u'set')
# (5, u'selling')
# (5, u'sale')
# (5, u'safety')
# (5, u'prepare')
# (5, u'place')
# (5, u'number')
# (5, u'next')
# (5, u'moving')
# (5, u'market')
# (5, u'love')
# (5, u'live')
# (5, u'let')
# (5, u'here')
# (5, u'had')
# (5, u'great')
# (5, u'give')
# (5, u'furniture')
# (5, u'few')
# (5, u'else')
# (5, u'easier')
# (5, u'down')
# (5, u'current')
# (5, u'could')
# (5, u'closing')
# (5, u'care')
# (5, u'been')
# (5, u'avoid')
# (5, u'area')
# (5, u'another')
# (5, u'These')
# (5, u'New')
# (5, u'In')
# (5, u'Check')
# (5, u'After')
# (5, u'2')
# (5, u'%')
# (4, u'worry')
# (4, u'won')
# (4, u'windows')
# (4, u'well')
# (4, u'week')
# (4, u'walk')
# (4, u'usually')
# (4, u'try')
# (4, u'trash')
# (4, u'top')
# (4, u'tips')
# (4, u'though')
# (4, u'target')
# (4, u'style')
# (4, u'structure')
# (4, u'src')
# (4, u'spend')
# (4, u'since')
# (4, u'rooms')
# (4, u'rent')
# (4, u'quality')
# (4, u'purchase')
# (4, u'problems')
# (4, u'positive')
# (4, u'past')
# (4, u'outlets')
# (4, u'organized')
# (4, u'options')
# (4, u'office')
# (4, u'off')
# (4, u'no')
# (4, u'neighbors')
# (4, u'mortgage')
# (4, u'money')
# (4, u'many')
# (4, u'making')
# (4, u'location')
# (4, u'levels')
# (4, u'large')
# (4, u'its')
# (4, u'issues')
# (4, u'investment')
# (4, u'inspector')
# (4, u'inside')
# (4, u'infographic')
# (4, u'img')
# (4, u'high')
# (4, u'having')
# (4, u'general')
# (4, u'garage')
# (4, u'floor')
# (4, u'figure')
# (4, u'exciting')
# (4, u'every')
# (4, u'especially')
# (4, u'ensure')
# (4, u'each')
# (4, u'dream')
# (4, u'done')
# (4, u'doesn')
# (4, u'credit')
# (4, u'costs')
# (4, u'costly')
# (4, u'cooking')
# (4, u'common')
# (4, u'close')
# (4, u'clients')
# (4, u'client')
# (4, u'clean')
# (4, u'children')
# (4, u'chemical')
# (4, u'checklist')
# (4, u'check')
# (4, u'centers')
# (4, u'between')
# (4, u'because')
# (4, u'back')
# (4, u'aspects')
# (4, u'already')
# (4, u'agents')
# (4, u'after')
# (4, u'afford')
# (4, u'advice')
# (4, u'additional')
# (4, u'_blank')
# (4, u'What')
# (4, u'To')
# (4, u'Take')
# (4, u'Once')
# (4, u'Now')
# (4, u'Not')
# (4, u'Maintenance')
# (4, u'How')
# (4, u'Here')
# (4, u'For')
# (4, u'Buying')
# (4, u'But')
# (4, u'Be')
# (4, u'5')
# (4, u'3')
# (4, u'1')
# (3, u'years')
# (3, u'world')
# (3, u'working')
# (3, u'welcomed')
# (3, u'very')
# (3, u'using')
# (3, u'use')
# (3, u'understand')
# (3, u'u2026')
# (3, u'u2019d')
# (3, u'towards')
# (3, u'together')
# (3, u'times')
# (3, u'thing')
# (3, u'then')
# (3, u'tend')
# (3, u'taxes')
# (3, u'surrounding')
# (3, u'summer')
# (3, u'specific')
# (3, u'someone')
# (3, u'shock')
# (3, u'she')
# (3, u'security')
# (3, u'secure')
# (3, u'school')
# (3, u'run')
# (3, u'restaurants')
# (3, u'research')
# (3, u'reports')
# (3, u'repairs')
# (3, u'renovations')
# (3, u'really')
# (3, u'question')
# (3, u'projects')
# (3, u'prevent')
# (3, u'prepared')
# (3, u'plans')
# (3, u'pest')
# (3, u'option')
# (3, u'often')
# (3, u'officer')
# (3, u'nice')
# (3, u'nearby')
# (3, u'movers')
# (3, u'mind')
# (3, u'means')
# (3, u'major')
# (3, u'maintaining')
# (3, u'made')
# (3, u'lost')
# (3, u'loan')
# (3, u'little')
# (3, u'line')
# (3, u'least')
# (3, u'learn')
# (3, u'lead')
# (3, u'lawn')
# (3, u'keep')
# (3, u'job')
# (3, u'instead')
# (3, u'increase')
# (3, u'included')
# (3, u'include')
# (3, u'ideal')
# (3, u'idea')
# (3, u'http://www.century21.com/real-estate-blog/wp-content/uploads/2016/01/C21_Jan_B2_Infographic_v2.png')
# (3, u'honest')
# (3, u'hobbies')
# (3, u'higher')
# (3, u'hear')
# (3, u'he')
# (3, u'guide')
# (3, u'growing')
# (3, u'grow')
# (3, u'going')
# (3, u'go')
# (3, u'garden')
# (3, u'front')
# (3, u'friends')
# (3, u'found')
# (3, u'following')
# (3, u'focus')
# (3, u'five')
# (3, u'fill')
# (3, u'experience')
# (3, u'excited')
# (3, u'events')
# (3, u'escrow')
# (3, u'errors')
# (3, u'entire')
# (3, u'enough')
# (3, u'enjoy')
# (3, u'early')
# (3, u'doors')
# (3, u'dishes')
# (3, u'difference')
# (3, u'determine')
# (3, u'decorated')
# (3, u'decision')
# (3, u'deal')
# (3, u'cords')
# (3, u'consider')
# (3, u'condition')
# (3, u'chlorine')
# (3, u'car')
# (3, u'cabinets')
# (3, u'cabinet')
# (3, u'budget')
# (3, u'bring')
# (3, u'both')
# (3, u'bit')
# (3, u'belongings')
# (3, u'behind')
# (3, u'beforehand')
# (3, u'backyard')
# (3, u'attached')
# (3, u'aren')
# (3, u'areas')
# (3, u'apartment')
# (3, u'answer')
# (3, u'always')
# (3, u'Their')
# (3, u'Space')
# (3, u'Some')
# (3, u'So')
# (3, u'Pack')
# (3, u'Open')
# (3, u'One')
# (3, u'Make')
# (3, u'Is')
# (3, u'However')
# (3, u'Having')
# (3, u'Have')
# (3, u'Fresh')
# (3, u'Do')
# (3, u'Disadvantages')
# (3, u'As')
# (3, u'Answer')
# (3, u'And')
# (3, u'Also')
# (3, u'Agents')
# (3, u'Advantages')
# (3, u'According')
# (3, u'20')
# (3, u'/')
# (3, u'-')
# (2, u'yourself')
# (2, u'yet')
# (2, u'year')
# (2, u'write-offs')
# (2, u'wouldn')
# (2, u'works')
# (2, u'within')
# (2, u'window')
# (2, u'willing')
# (2, u'weather')
# (2, u'walls')
# (2, u'vs')
# (2, u'vision')
# (2, u'versus')
# (2, u'vacation')
# (2, u'utilities')
# (2, u'used')
# (2, u'urban')
# (2, u'unexpected')
# (2, u'underneath')
# (2, u'under')
# (2, u'type')
# (2, u'turn')
# (2, u'treat')
# (2, u'travel')
# (2, u'track')
# (2, u'toxic')
# (2, u'topics')
# (2, u'tools')
# (2, u'to-do')
# (2, u'throughout')
# (2, u'three')
# (2, u'test')
# (2, u'tell')
# (2, u'tasks')
# (2, u'task')
# (2, u'takes')
# (2, u'system')
# (2, u'supplies')
# (2, u'stuff')
# (2, u'structural')
# (2, u'store')
# (2, u'stop')
# (2, u'stock')
# (2, u'steps')
# (2, u'status')
# (2, u'state')
# (2, u'starting')
# (2, u'sounds')
# (2, u'solid')
# (2, u'smoother')
# (2, u'smaller')
# (2, u'slowly')
# (2, u'size')
# (2, u'sink')
# (2, u'singles')
# (2, u'simple')
# (2, u'similar')
# (2, u'signed')
# (2, u'sign')
# (2, u'shopping')
# (2, u'sharing')
# (2, u'shape')
# (2, u'settle')
# (2, u'serve')
# (2, u'sense')
# (2, u'seem')
# (2, u'seeing')
# (2, u'searching')
# (2, u'search')
# (2, u'scrub')
# (2, u'score')
# (2, u'schools')
# (2, u'scene')
# (2, u'save')
# (2, u'safer')
# (2, u'rugs')
# (2, u'roofs')
# (2, u'rid')
# (2, u'responsibilities')
# (2, u'renting')
# (2, u'relationship')
# (2, u'recommend')
# (2, u'read')
# (2, u'range')
# (2, u'quiet')
# (2, u'putting')
# (2, u'put')
# (2, u'puppies')
# (2, u'property')
# (2, u'properties')
# (2, u'productive')
# (2, u'problem')
# (2, u'probably')
# (2, u'price')
# (2, u'potentially')
# (2, u'possible')
# (2, u'pools')
# (2, u'points')
# (2, u'plumbing')
# (2, u'players')
# (2, u'play')
# (2, u'plants')
# (2, u'planning')
# (2, u'plan')
# (2, u'pills')
# (2, u'pieces')
# (2, u'piece')
# (2, u'photos')
# (2, u'pay')
# (2, u'part')
# (2, u'park')
# (2, u'packing')
# (2, u'owners')
# (2, u'overwhelming')
# (2, u'overall')
# (2, u'oven')
# (2, u'outside')
# (2, u'opportunity')
# (2, u'opening')
# (2, u'obvious')
# (2, u'nothing')
# (2, u'normal')
# (2, u'never')
# (2, u'neighbor')
# (2, u'negotiate')
# (2, u'necessity')
# (2, u'navigate')
# (2, u'nature')
# (2, u'named')
# (2, u'nThis')
# (2, u'nAlthough')
# (2, u'moved')
# (2, u'momentum')
# (2, u'miss')
# (2, u'measurements')
# (2, u'mean')
# (2, u'meals')
# (2, u'mansion')
# (2, u'lower')
# (2, u'longer')
# (2, u'locks')
# (2, u'locate')
# (2, u'listings')
# (2, u'listen')
# (2, u'listed')
# (2, u'limited')
# (2, u'lids')
# (2, u'lender')
# (2, u'leaving')
# (2, u'leaves')
# (2, u'later')
# (2, u'larger')
# (2, u'lamps')
# (2, u'key')
# (2, u'island')
# (2, u'invest')
# (2, u'interests')
# (2, u'interested')
# (2, u'interest')
# (2, u'insurance')
# (2, u'insight')
# (2, u'impressive')
# (2, u'imagine')
# (2, u'huge')
# (2, u'http://www.century21.com/calculators/rentvsbuy')
# (2, u'http://www.century21.com/buyingadvice')
# (2, u'history')
# (2, u'his')
# (2, u'highlight')
# (2, u'helps')
# (2, u'harmful')
# (2, u'goal')
# (2, u'gives')
# (2, u'fun')
# (2, u'forget')
# (2, u'food')
# (2, u'follow')
# (2, u'floors')
# (2, u'fits')
# (2, u'fitness')
# (2, u'filled')
# (2, u'fees')
# (2, u'far')
# (2, u'facts')
# (2, u'eye')
# (2, u'exterior')
# (2, u'expect')
# (2, u'exercise')
# (2, u'example')
# (2, u'ever')
# (2, u'etc')
# (2, u'entertainment')
# (2, u'enter')
# (2, u'end')
# (2, u'electrical')
# (2, u'either')
# (2, u'due')
# (2, u'drawers')
# (2, u'double')
# (2, u'dotted')
# (2, u'doing')
# (2, u'documents')
# (2, u'distract')
# (2, u'direction')
# (2, u'didn')
# (2, u'delicious')
# (2, u'decreases')
# (2, u'decrease')
# (2, u'decorate')
# (2, u'daunting')
# (2, u'date')
# (2, u'damage')
# (2, u'curious')
# (2, u'crucial')
# (2, u'creatures')
# (2, u'created')
# (2, u'covered')
# (2, u'counter')
# (2, u'couldn')
# (2, u'cooling')
# (2, u'cook')
# (2, u'concern')
# (2, u'company')
# (2, u'community')
# (2, u'commit')
# (2, u'commercial')
# (2, u'comfortable')
# (2, u'closet')
# (2, u'closer')
# (2, u'closed')
# (2, u'cleaning')
# (2, u'city')
# (2, u'choose')
# (2, u'china')
# (2, u'chemistry')
# (2, u'chemicals')
# (2, u'cater')
# (2, u'case')
# (2, u'cans')
# (2, u'businesses')
# (2, u'bungalow')
# (2, u'building')
# (2, u'breaker')
# (2, u'boxes')
# (2, u'bills')
# (2, u'bigger')
# (2, u'bid')
# (2, u'below')
# (2, u'beautiful')
# (2, u'basement')
# (2, u'bar')
# (2, u'bacteria')
# (2, u'baby')
# (2, u'aware')
# (2, u'attend')
# (2, u'article')
# (2, u'architecture')
# (2, u'apps')
# (2, u'appraiser')
# (2, u'apply')
# (2, u'answers')
# (2, u'amount')
# (2, u'alt')
# (2, u'allow')
# (2, u'alkalinity')
# (2, u'ahead')
# (2, u'advance')
# (2, u'addition')
# (2, u'add')
# (2, u'access')
# (2, u'able')
# (2, u'YOY')
# (2, u'Which')
# (2, u'Whether')
# (2, u'Where')
# (2, u'Use')
# (2, u'Under')
# (2, u'Texan')
# (2, u'Test')
# (2, u'Storage')
# (2, u'Sri')
# (2, u'Since')
# (2, u'Show')
# (2, u'September')
# (2, u'Realty')
# (2, u'Read')
# (2, u'Privacy')
# (2, u'Prices')
# (2, u'Pool')
# (2, u'Place')
# (2, u'Peak')
# (2, u'Outlets')
# (2, u'Our')
# (2, u'October')
# (2, u'Moving')
# (2, u'Most')
# (2, u'Luckily')
# (2, u'Los')
# (2, u'Looks')
# (2, u'Looking')
# (2, u'Level')
# (2, u'Last')
# (2, u'Lanka')
# (2, u'Kitchen')
# (2, u'Just')
# (2, u'July')
# (2, u'Homeowner')
# (2, u'High')
# (2, u'Hidden')
# (2, u'HOA')
# (2, u'Florida')
# (2, u'Flashman')
# (2, u'Day')
# (2, u'Dallas')
# (2, u'Dad')
# (2, u'Congratulations')
# (2, u'Commercial')
# (2, u'Colorado')
# (2, u'Centers')
# (2, u'Can')
# (2, u'Cabinets')
# (2, u'CMO')
# (2, u'C21')
# (2, u'Business')
# (2, u'Being')
# (2, u'Before')
# (2, u'Beach')
# (2, u'Association')
# (2, u'Ask')
# (2, u'Angeles')
# (2, u';')
# (2, u'736px')
# (2, u'6')
# (2, u'4')
# (2, u'2017')
# (2, u'2016')
# (2, u'2015')
# (1, u'yours')
# (1, u'yes')
# (1, u'yard')
# (1, u'xa9')
# (1, u'xa0News')
# (1, u'www.century21.com')
# (1, u'wrong')
# (1, u'write')
# (1, u'wp-image')
# (1, u'worthy')
# (1, u'worried')
# (1, u'words')
# (1, u'word')
# (1, u'wood')
# (1, u'wondering')
# (1, u'wishing')
# (1, u'wish')
# (1, u'wise')
# (1, u'wires')
# (1, u'winning')
# (1, u'winners')
# (1, u'width')
# (1, u'why')
# (1, u'wherever')
# (1, u'were')
# (1, u'well-lit')
# (1, u'well-being')
# (1, u'welcome')
# (1, u'weekly')
# (1, u'weeds')
# (1, u'website')
# (1, u'weapon')
# (1, u'weakest')
# (1, u'ways')
# (1, u'waving')
# (1, u'waterproof')
# (1, u'watchful')
# (1, u'washing')
# (1, u'warmth')
# (1, u'wants')
# (1, u'wand')
# (1, u'wallpaper')
# (1, u'wall')
# (1, u'vital')
# (1, u'visits')
# (1, u'visiting')
# (1, u'village')
# (1, u'view')
# (1, u'version')
# (1, u'verbally')
# (1, u'verbal')
# (1, u'vegetables')
# (1, u'vary')
# (1, u'various')
# (1, u'vapors')
# (1, u'van')
# (1, u'value')
# (1, u'vacuum')
# (1, u'upscale')
# (1, u'upkeep')
# (1, u'updated')
# (1, u'unusually')
# (1, u'unsure')
# (1, u'unprepared')
# (1, u'unpacking')
# (1, u'units')
# (1, u'united')
# (1, u'unit')
# (1, u'union')
# (1, u'undertones')
# (1, u'u2026own')
# (1, u'u2026except')
# (1, u'u201cwants')
# (1, u'u201cone')
# (1, u'u201cneeds')
# (1, u'u201cmust')
# (1, u'u201cjust')
# (1, u'u201cfair')
# (1, u'u201cIt')
# (1, u'u201cHome')
# (1, u'u201cGive')
# (1, u'u2019')
# (1, u'u2014the')
# (1, u'u2014setting')
# (1, u'typically')
# (1, u'typical')
# (1, u'types')
# (1, u'tykes')
# (1, u'twice')
# (1, u'turning')
# (1, u'turkey')
# (1, u'tuned')
# (1, u'tuck')
# (1, u'trying')
# (1, u'truthful')
# (1, u'triple-check')
# (1, u'treasured')
# (1, u'transportation')
# (1, u'trained')
# (1, u'townhouse')
# (1, u'toward')
# (1, u'total')
# (1, u'took')
# (1, u'tone')
# (1, u'toilet')
# (1, u'timeless')
# (1, u'time-consuming')
# (1, u'tight')
# (1, u'thumb')
# (1, u'thought')
# (1, u'thirty')
# (1, u'thermostat')
# (1, u'thanks')
# (1, u'th')
# (1, u'text')
# (1, u'territories')
# (1, u'terms')
# (1, u'temptations')
# (1, u'temperatures')
# (1, u'technology')
# (1, u'tearing')
# (1, u'tape')
# (1, u'talking')
# (1, u'talk')
# (1, u'taking')
# (1, u'taken')
# (1, u'sweet')
# (1, u'sweat')
# (1, u'swallowed')
# (1, u'suspicious')
# (1, u'surroundings')
# (1, u'surprise')
# (1, u'sunshine')
# (1, u'sunlight')
# (1, u'sunken')
# (1, u'summertime')
# (1, u'suitcase')
# (1, u'successful')
# (1, u'suburbs')
# (1, u'substantial')
# (1, u'studios')
# (1, u'strong')
# (1, u'stressful')
# (1, u'stress-free')
# (1, u'streets')
# (1, u'storm')
# (1, u'stored')
# (1, u'storage')
# (1, u'stools')
# (1, u'stolen')
# (1, u'still')
# (1, u'stereotype')
# (1, u'stellar')
# (1, u'stays')
# (1, u'staying')
# (1, u'stated')
# (1, u'starring')
# (1, u'standing')
# (1, u'standalone')
# (1, u'stand')
# (1, u'stairwells')
# (1, u'stairs')
# (1, u'staged')
# (1, u'srcset')
# (1, u'square')
# (1, u'sprinkler')
# (1, u'sprays')
# (1, u'spotlight')
# (1, u'splashing')
# (1, u'spent')
# (1, u'specifically')
# (1, u'special')
# (1, u'speak')
# (1, u'spaces')
# (1, u'source')
# (1, u'sound')
# (1, u'sooner')
# (1, u'somewhat')
# (1, u'sometimes')
# (1, u'solution')
# (1, u'solely')
# (1, u'sofa')
# (1, u'soccer')
# (1, u'smoothly')
# (1, u'skimmer')
# (1, u'skills')
# (1, u'skill')
# (1, u'sizes')
# (1, u'size-full')
# (1, u'sitting')
# (1, u'sipping')
# (1, u'simply')
# (1, u'silverware')
# (1, u'signs')
# (1, u'significantly')
# (1, u'siding')
# (1, u'sidewalks')
# (1, u'sides')
# (1, u'side')
# (1, u'showings')
# (1, u'showing')
# (1, u'showcasing')
# (1, u'showcase')
# (1, u'show')
# (1, u'shouldn')
# (1, u'short')
# (1, u'shoes')
# (1, u'shocks')
# (1, u'shift')
# (1, u'shared')
# (1, u'shag')
# (1, u'severe')
# (1, u'settled')
# (1, u'sets')
# (1, u'serious')
# (1, u'separate')
# (1, u'sentimental')
# (1, u'sensor')
# (1, u'sending')
# (1, u'seemingly')
# (1, u'seek')
# (1, u'second')
# (1, u'season')
# (1, u'scores')
# (1, u'scored')
# (1, u'saying')
# (1, u'say')
# (1, u'saw')
# (1, u'savings')
# (1, u'sanitizer')
# (1, u'sacrifice')
# (1, u'rules')
# (1, u'rule')
# (1, u'rubber')
# (1, u'row')
# (1, u'routine')
# (1, u'round')
# (1, u'roof')
# (1, u'rolls')
# (1, u'role')
# (1, u'rodents')
# (1, u'robot')
# (1, u'roasting')
# (1, u'roads')
# (1, u'road')
# (1, u'rewarding')
# (1, u'reviews')
# (1, u'review')
# (1, u'returning')
# (1, u'return')
# (1, u'retrieve')
# (1, u'restating')
# (1, u'rest')
# (1, u'responsible')
# (1, u'responsibility')
# (1, u'respectively')
# (1, u'resources')
# (1, u'researching')
# (1, u'require')
# (1, u'report')
# (1, u'replacing')
# (1, u'replacement')
# (1, u'replace')
# (1, u'repaving')
# (1, u'renovation')
# (1, u'remove')
# (1, u'rely')
# (1, u'relieved')
# (1, u'reliant')
# (1, u'relaxing')
# (1, u'relationships')
# (1, u'rejuvenating')
# (1, u'regarding')
# (1, u'reflects')
# (1, u'refilling')
# (1, u'referrals')
# (1, u'recreation')
# (1, u'record')
# (1, u'recommended')
# (1, u'recently')
# (1, u'recent')
# (1, u'reasons')
# (1, u'reasonable')
# (1, u'reason')
# (1, u'reality')
# (1, u'reading')
# (1, u'rather')
# (1, u'rates')
# (1, u'rate')
# (1, u'rare')
# (1, u'ranging')
# (1, u'rambunctious')
# (1, u'raise')
# (1, u'rain')
# (1, u'quiz')
# (1, u'quite')
# (1, u'quickly')
# (1, u'quarters')
# (1, u'qualities')
# (1, u'qualify')
# (1, u'qualified')
# (1, u'purse')
# (1, u'purposes')
# (1, u'purchasing')
# (1, u'purchased')
# (1, u'pump')
# (1, u'pulled')
# (1, u'public')
# (1, u'providers')
# (1, u'provided')
# (1, u'provide')
# (1, u'proudly')
# (1, u'protection')
# (1, u'pros')
# (1, u'proof')
# (1, u'prone')
# (1, u'promptly')
# (1, u'promised')
# (1, u'program')
# (1, u'professionals')
# (1, u'producer')
# (1, u'privacy')
# (1, u'pristinely')
# (1, u'priority')
# (1, u'priorities')
# (1, u'pretty')
# (1, u'press')
# (1, u'president')
# (1, u'prescription')
# (1, u'preparing')
# (1, u'preferences')
# (1, u'prefer')
# (1, u'predict')
# (1, u'precautions')
# (1, u'pre-approved')
# (1, u'practicality')
# (1, u'practical')
# (1, u'pouring')
# (1, u'pots')
# (1, u'potatoes')
# (1, u'pot')
# (1, u'possessions')
# (1, u'pose')
# (1, u'portray')
# (1, u'poisonous')
# (1, u'poised')
# (1, u'pointed')
# (1, u'point')
# (1, u'plug')
# (1, u'plenty')
# (1, u'playing')
# (1, u'placement')
# (1, u'placed')
# (1, u'pipes')
# (1, u'pile')
# (1, u'picking')
# (1, u'picked')
# (1, u'physical')
# (1, u'pets')
# (1, u'pertinent')
# (1, u'perks')
# (1, u'perk')
# (1, u'periods')
# (1, u'perhaps')
# (1, u'pen')
# (1, u'pedestrians')
# (1, u'peak')
# (1, u'peace')
# (1, u'payment')
# (1, u'paths')
# (1, u'path')
# (1, u'party')
# (1, u'parts')
# (1, u'particularly')
# (1, u'paramount')
# (1, u'paperwork')
# (1, u'paper')
# (1, u'pans')
# (1, u'panels')
# (1, u'paired')
# (1, u'painting')
# (1, u'paint')
# (1, u'owning')
# (1, u'overwhelmed')
# (1, u'overwhelm')
# (1, u'overlook')
# (1, u'overflowing')
# (1, u'over-the-counter')
# (1, u'ovens')
# (1, u'outlooks')
# (1, u'outlet')
# (1, u'others')
# (1, u'order')
# (1, u'opposed')
# (1, u'opinion')
# (1, u'open-ended')
# (1, u'onto')
# (1, u'online')
# (1, u'offices')
# (1, u'offer')
# (1, u'odds')
# (1, u'occasionally')
# (1, u'object')
# (1, u'oasis')
# (1, u'numbers')
# (1, u'nowadays')
# (1, u'now')
# (1, u'notice')
# (1, u'note')
# (1, u'norm')
# (1, u'nontoxic')
# (1, u'noise')
# (1, u'nightlife')
# (1, u'night')
# (1, u'niche')
# (1, u'newer')
# (1, u'neighborhoods')
# (1, u'negatives')
# (1, u'neck')
# (1, u'necessary')
# (1, u'neatly')
# (1, u'nearest')
# (1, u'nd')
# (1, u'naturally')
# (1, u'natural')
# (1, u'nationwide')
# (1, u'narrow')
# (1, u'name')
# (1, u'nWith')
# (1, u'nWhile')
# (1, u'nUnlike')
# (1, u'nPotential')
# (1, u'nCouples')
# (1, u'nClosing')
# (1, u'nCertain')
# (1, u'nAvoid')
# (1, u'must-have')
# (1, u'must')
# (1, u'museums')
# (1, u'multiple')
# (1, u'mow')
# (1, u'movement')
# (1, u'move-in')
# (1, u'mortgages')
# (1, u'morning')
# (1, u'monthly')
# (1, u'moment')
# (1, u'modern')
# (1, u'mistake')
# (1, u'missed')
# (1, u'misinformation')
# (1, u'mirror')
# (1, u'minor')
# (1, u'minimalist')
# (1, u'millennials')
# (1, u'millennial')
# (1, u'milestone')
# (1, u'metropolis')
# (1, u'messages')
# (1, u'merger')
# (1, u'mention')
# (1, u'memory')
# (1, u'memorable')
# (1, u'membership')
# (1, u'members')
# (1, u'meeting')
# (1, u'meet')
# (1, u'medicine')
# (1, u'medications')
# (1, u'medication')
# (1, u'measure')
# (1, u'meant')
# (1, u'maybe')
# (1, u'maximum')
# (1, u'max-width')
# (1, u'matters')
# (1, u'matter')
# (1, u'material')
# (1, u'matching')
# (1, u'matches')
# (1, u'martial')
# (1, u'marble')
# (1, u'managed')
# (1, u'manage')
# (1, u'makes')
# (1, u'maintained')
# (1, u'maintain')
# (1, u'main')
# (1, u'lying')
# (1, u'luxury')
# (1, u'low')
# (1, u'looks')
# (1, u'lookout')
# (1, u'located')
# (1, u'listing')
# (1, u'link')
# (1, u'likes')
# (1, u'likelihood')
# (1, u'lights')
# (1, u'life')
# (1, u'lid')
# (1, u'letting')
# (1, u'lesson')
# (1, u'lenders')
# (1, u'lemonade')
# (1, u'left')
# (1, u'leave')
# (1, u'leaky')
# (1, u'leaders')
# (1, u'law')
# (1, u'lava')
# (1, u'latter')
# (1, u'late')
# (1, u'laps')
# (1, u'landscaping')
# (1, u'label')
# (1, u'known')
# (1, u'knowledgeable')
# (1, u'knowledge')
# (1, u'knowing')
# (1, u'knit')
# (1, u'kit')
# (1, u'kill')
# (1, u'kids')
# (1, u'keys')
# (1, u'keeps')
# (1, u'keeping')
# (1, u'jeans')
# (1, u'irksome')
# (1, u'involved')
# (1, u'involve')
# (1, u'invigorating')
# (1, u'intricate')
# (1, u'interiors')
# (1, u'interact')
# (1, u'intentionally')
# (1, u'integrity')
# (1, u'insulated')
# (1, u'instant')
# (1, u'installing')
# (1, u'installed')
# (1, u'install')
# (1, u'inspire')
# (1, u'inspection')
# (1, u'inspected')
# (1, u'inspect')
# (1, u'insects')
# (1, u'inquiries')
# (1, u'initially')
# (1, u'infestation')
# (1, u'industry')
# (1, u'individual')
# (1, u'indication')
# (1, u'indicate')
# (1, u'independence')
# (1, u'incredible')
# (1, u'increases')
# (1, u'increased')
# (1, u'inconvenient')
# (1, u'income')
# (1, u'inclusive')
# (1, u'including')
# (1, u'impurities')
# (1, u'improvements')
# (1, u'importantly')
# (1, u'importance')
# (1, u'implement')
# (1, u'imperative')
# (1, u'ideas')
# (1, u'i')
# (1, u'hundred')
# (1, u'human')
# (1, u'hub')
# (1, u'http://www.homeadvisor.com/r/new-homeowner-tips-avoid-mistakes/')
# (1, u'http://www.homeadvisor.com/r/how-to-save-money-with-home-maintenance/')
# (1, u'http://www.homeadvisor.com/r/home-buyer-quiz-tips-for-new-homeowners/')
# (1, u'http://www.century21.com/real-estate-blog/wp-content/uploads/2016/01/C21_Jan_B2_Infographic_v2-462x1024.png')
# (1, u'http://www.century21.com/real-estate-blog/wp-content/uploads/2016/01/C21_Jan_B2_Infographic_v2-195x431.png')
# (1, u'http://www.century21.com/real-estate-blog/wp-content/uploads/2016/01/C21_Jan_B2_Infographic_v2-135x300.png')
# (1, u'http://www.century21.com/real-estate-blog/things-your-inspector-missed-that-you-can-still-catch/')
# (1, u'http://www.century21.com/real-estate-blog/on-the-road-again-the-ultimate-moving-checklist/')
# (1, u'http://www.century21.com/real-estate-blog/new-home-checklist-needs-and-wants/')
# (1, u'http://www.century21.com/real-estate-blog/moving-advice-you-should-not-take-from-people-in-stock-photos/')
# (1, u'http://www.century21.com/real-estate-blog/how-to-build-a-winning-home-buying-team/')
# (1, u'http://www.century21.com/real-estate-blog/2014/11/things-your-inspector-missed-that-you-can-still-catch/')
# (1, u'http://www.century21.com/real-estate-blog/2014/11/inspection-protection-2/')
# (1, u'http://www.century21.com/real-estate-blog/2014/08/benefits-of-working-with-a-real-estate-agent/')
# (1, u'http://www.century21.com/buyingadvice/lookingforahome/afford')
# (1, u'http://www.cdc.gov/healthywater/swimming/pools/disinfection-team-chlorine-ph.html')
# (1, u'http://i.imgur.com/i8VEWb3.png"/')
# (1, u'http://i.imgur.com/i8VEWb3.png')
# (1, u'http://i.imgur.com/gm00u8S.png"/')
# (1, u'http://i.imgur.com/gm00u8S.png')
# (1, u'http://i.imgur.com/5BqoUs1.png"/')
# (1, u'http://i.imgur.com/5BqoUs1.png')
# (1, u'http://freshome.com/2014/06/20/10-pool-maintenance-tips-need-try-right-now/')
# (1, u'http://bit.ly/2elDwGK')
# (1, u'http://bit.ly/2da9rwb')
# (1, u'http://bit.ly/2da7kZm')
# (1, u'http://bit.ly/2dN4QiO')
# (1, u'http://bit.ly/2cRAuJS')
# (1, u'http://bit.ly/1OaAEMe')
# (1, u'household')
# (1, u'hours')
# (1, u'hospitals')
# (1, u'hose')
# (1, u'hope')
# (1, u'honored')
# (1, u'honestly')
# (1, u'holiday')
# (1, u'hold')
# (1, u'hitting')
# (1, u'hiring')
# (1, u'hire')
# (1, u'highways')
# (1, u'hiding')
# (1, u'hidden')
# (1, u'her')
# (1, u'helping')
# (1, u'helpful')
# (1, u'heightened')
# (1, u'height')
# (1, u'heating')
# (1, u'heater')
# (1, u'heat')
# (1, u'heart')
# (1, u'hearing')
# (1, u'heard')
# (1, u'healthcare')
# (1, u'headache')
# (1, u'hassle')
# (1, u'harsh')
# (1, u'harm')
# (1, u'hardness')
# (1, u'harder')
# (1, u'happy')
# (1, u'happier')
# (1, u'happenings')
# (1, u'happening')
# (1, u'haphazardly')
# (1, u'handled')
# (1, u'hand')
# (1, u'halfway')
# (1, u'gutters')
# (1, u'guesswork')
# (1, u'growth')
# (1, u'grown')
# (1, u'ground-breaking')
# (1, u'greater')
# (1, u'grapes')
# (1, u'grade')
# (1, u'got')
# (1, u'glassware')
# (1, u'glass')
# (1, u'glance')
# (1, u'glamorous')
# (1, u'giving')
# (1, u'given')
# (1, u'gift')
# (1, u'gets')
# (1, u'generally')
# (1, u'gauge')
# (1, u'gate')
# (1, u'gardening')
# (1, u'game')
# (1, u'gaining')
# (1, u'further')
# (1, u'furry')
# (1, u'functional')
# (1, u'function')
# (1, u'full')
# (1, u'fruits')
# (1, u'friend')
# (1, u'frequenting')
# (1, u'free')
# (1, u'franchises')
# (1, u'franchise')
# (1, u'frame')
# (1, u'foundation')
# (1, u'forms')
# (1, u'former')
# (1, u'footage')
# (1, u'focused')
# (1, u'fly')
# (1, u'fluctuate')
# (1, u'flooded')
# (1, u'floating')
# (1, u'fixer-upper')
# (1, u'fix')
# (1, u'first-time')
# (1, u'firm')
# (1, u'finished')
# (1, u'financially')
# (1, u'financial')
# (1, u'finally')
# (1, u'finalist')
# (1, u'fight')
# (1, u'fielding')
# (1, u'feet')
# (1, u'feeling')
# (1, u'fee')
# (1, u'fawn')
# (1, u'favorite')
# (1, u'favor')
# (1, u'faucet')
# (1, u'fast')
# (1, u'fail')
# (1, u'factor')
# (1, u'facing')
# (1, u'facility')
# (1, u'face')
# (1, u'extravagant')
# (1, u'extra')
# (1, u'explore')
# (1, u'expertise')
# (1, u'experiences')
# (1, u'expenses')
# (1, u'expedite')
# (1, u'expansion')
# (1, u'expanded')
# (1, u'exists')
# (1, u'exclusively')
# (1, u'excess')
# (1, u'excellent')
# (1, u'examine')
# (1, u'exactly')
# (1, u'event')
# (1, u'evaluation')
# (1, u'evaluating')
# (1, u'estimate')
# (1, u'essentials')
# (1, u'essential')
# (1, u'escaping')
# (1, u'errands')
# (1, u'envision')
# (1, u'entry')
# (1, u'entrance')
# (1, u'entirely')
# (1, u'entertain')
# (1, u'enjoyable')
# (1, u'enhance')
# (1, u'emphasis')
# (1, u'elicit')
# (1, u'electronics')
# (1, u'electric')
# (1, u'efficient')
# (1, u'effect')
# (1, u'editorial')
# (1, u'edge')
# (1, u'economically')
# (1, u'echoed')
# (1, u'eating')
# (1, u'eat')
# (1, u'e')
# (1, u'dwellers')
# (1, u'dweller')
# (1, u'duct')
# (1, u'drop')
# (1, u'driving')
# (1, u'driveways')
# (1, u'drivers')
# (1, u'drive')
# (1, u'drafty')
# (1, u'double-check')
# (1, u'doorways')
# (1, u'dogs')
# (1, u'diverse')
# (1, u'district')
# (1, u'distracted')
# (1, u'distinguishes')
# (1, u'distance')
# (1, u'disputes')
# (1, u'display')
# (1, u'discuss')
# (1, u'disadvantages')
# (1, u'dirt')
# (1, u'directly')
# (1, u'dinners')
# (1, u'dinner')
# (1, u'dine')
# (1, u'diluting')
# (1, u'dilapidated')
# (1, u'digit')
# (1, u'differing')
# (1, u'differ')
# (1, u'developed')
# (1, u'detect')
# (1, u'details')
# (1, u'detailed')
# (1, u'detached')
# (1, u'despite')
# (1, u'desirable')
# (1, u'designated')
# (1, u'design')
# (1, u'describe')
# (1, u'depends')
# (1, u'depend')
# (1, u'departments')
# (1, u'demographic')
# (1, u'delved')
# (1, u'delays')
# (1, u'deep')
# (1, u'decor')
# (1, u'deck')
# (1, u'decision-making')
# (1, u'debris')
# (1, u'dealt')
# (1, u'dangling')
# (1, u'dangers')
# (1, u'dangerously')
# (1, u'dance')
# (1, u'damaged')
# (1, u'cyanuric')
# (1, u'cuts')
# (1, u'curb')
# (1, u'cumbersome')
# (1, u'cultural')
# (1, u'crumbling')
# (1, u'crock')
# (1, u'create')
# (1, u'crack')
# (1, u'covers')
# (1, u'coupled')
# (1, u'country')
# (1, u'countries')
# (1, u'counterparts')
# (1, u'cost')
# (1, u'conversation')
# (1, u'convenient')
# (1, u'controls')
# (1, u'contributed')
# (1, u'contracts')
# (1, u'contract')
# (1, u'continue')
# (1, u'contain')
# (1, u'constantly')
# (1, u'constant')
# (1, u'consistently')
# (1, u'considerations')
# (1, u'cons')
# (1, u'connectivity')
# (1, u'connected')
# (1, u'confusing')
# (1, u'confused')
# (1, u'condo')
# (1, u'concerns')
# (1, u'computers')
# (1, u'components')
# (1, u'complicated')
# (1, u'complaining')
# (1, u'compiled')
# (1, u'comparing')
# (1, u'communities')
# (1, u'communication')
# (1, u'communicate')
# (1, u'communal')
# (1, u'commonplace')
# (1, u'comfortably')
# (1, u'combined')
# (1, u'colors')
# (1, u'color')
# (1, u'collection')
# (1, u'cohabiting')
# (1, u'cobblestone')
# (1, u'coats')
# (1, u'cluttered')
# (1, u'clothes')
# (1, u'closest')
# (1, u'closely')
# (1, u'close-knit')
# (1, u'classy')
# (1, u'classes')
# (1, u'circuit')
# (1, u'choosing')
# (1, u'chocolate')
# (1, u'child-proof')
# (1, u'chic')
# (1, u'chewing')
# (1, u'charges')
# (1, u'changes')
# (1, u'change')
# (1, u'chance')
# (1, u'central')
# (1, u'center')
# (1, u'celebrity')
# (1, u'celebrate')
# (1, u'ceilings')
# (1, u'catch')
# (1, u'carpets')
# (1, u'caring')
# (1, u'cares')
# (1, u'cards')
# (1, u'capitalizes')
# (1, u'campaign')
# (1, u'came')
# (1, u'calculator')
# (1, u'calcium')
# (1, u'c2')
# (1, u'buys')
# (1, u'bustling')
# (1, u'burns')
# (1, u'bulk')
# (1, u'build-up')
# (1, u'budgeting')
# (1, u'buddy')
# (1, u'brokerage')
# (1, u'brightly-colored')
# (1, u'bright')
# (1, u'break')
# (1, u'box')
# (1, u'bowls')
# (1, u'bounce')
# (1, u'bottom')
# (1, u'bottles')
# (1, u'born')
# (1, u'boosts')
# (1, u'boomer')
# (1, u'book')
# (1, u'board')
# (1, u'blender')
# (1, u'bidder')
# (1, u'benefit')
# (1, u'beneficial')
# (1, u'beneath')
# (1, u'believe')
# (1, u'begin')
# (1, u'bedrooms')
# (1, u'become')
# (1, u'beachside')
# (1, u'beach')
# (1, u'bathroom')
# (1, u'basket')
# (1, u'bars')
# (1, u'bank')
# (1, u'bands')
# (1, u'azalea')
# (1, u'awareness')
# (1, u'available')
# (1, u'attractive')
# (1, u'attorney')
# (1, u'attention')
# (1, u'attending')
# (1, u'attachment')
# (1, u'attach')
# (1, u'assisted')
# (1, u'aspect')
# (1, u'asks')
# (1, u'asked')
# (1, u'artwork')
# (1, u'arts')
# (1, u'arranged')
# (1, u'approval')
# (1, u'appropriate')
# (1, u'approaching')
# (1, u'appreciating')
# (1, u'appeal')
# (1, u'app')
# (1, u'apart')
# (1, u'anticipate')
# (1, u'answered')
# (1, u'announce')
# (1, u'anecdotes')
# (1, u'ample')
# (1, u'along')
# (1, u'allows')
# (1, u'all-inclusive')
# (1, u'aligncenter')
# (1, u'algae')
# (1, u'agreements')
# (1, u'aging')
# (1, u'aggressive')
# (1, u'age')
# (1, u'against')
# (1, u'again')
# (1, u'affect')
# (1, u'advised')
# (1, u'advantages')
# (1, u'adult')
# (1, u'adding')
# (1, u'added')
# (1, u'active')
# (1, u'acidity')
# (1, u'acid')
# (1, u'accurately')
# (1, u'account')
# (1, u'accordingly')
# (1, u'accordance')
# (1, u'accomplishments')
# (1, u'accessible')
# (1, u'accepted')
# (1, u'accept')
# (1, u'abundant')
# (1, u'absent')
# (1, u'abode')
# (1, u'ability')
# (1, u'Zealand')
# (1, u'Yes')
# (1, u'Year')
# (1, u'Wouldn')
# (1, u'Women')
# (1, u'Windows')
# (1, u'Will')
# (1, u'Wieder')
# (1, u'Who')
# (1, u'Whitley')
# (1, u'Whatever')
# (1, u'Wellington')
# (1, u'Water')
# (1, u'Visit')
# (1, u'Virginia')
# (1, u'Value')
# (1, u'Utility')
# (1, u'Until')
# (1, u'Unfortunately')
# (1, u'Underestimating')
# (1, u'Ultimate')
# (1, u'U')
# (1, u'Two')
# (1, u'Try')
# (1, u'Trusting')
# (1, u'Triton')
# (1, u'Transportation')
# (1, u'Townhouse')
# (1, u'Top')
# (1, u'Toilet')
# (1, u'Today')
# (1, u'Tip')
# (1, u'Three')
# (1, u'Thought-out')
# (1, u'Those')
# (1, u'Think')
# (1, u'Things')
# (1, u'Texas')
# (1, u'Team')
# (1, u'Tax')
# (1, u'Talk')
# (1, u'TV')
# (1, u'Sweet')
# (1, u'Sweating')
# (1, u'Structural')
# (1, u'Stevie')
# (1, u'Stay')
# (1, u'Star')
# (1, u'Springs')
# (1, u'Spouts')
# (1, u'Southern')
# (1, u'Source')
# (1, u'Something')
# (1, u'Smaller')
# (1, u'Skipping')
# (1, u'Skim')
# (1, u'Sinks')
# (1, u'Sink')
# (1, u'Single')
# (1, u'Sidewalks')
# (1, u'Shreve')
# (1, u'Shopping')
# (1, u'Shock')
# (1, u'Sharing')
# (1, u'Secure')
# (1, u'Scrubbing')
# (1, u'Scrub')
# (1, u'Schools')
# (1, u'Schedule')
# (1, u'Sales')
# (1, u'Safety')
# (1, u'SMARTER.BOLDER.FASTER')
# (1, u'S')
# (1, u'Runoff')
# (1, u'Rugs')
# (1, u'Roads')
# (1, u'Restaurants')
# (1, u'Research')
# (1, u'Renting')
# (1, u'Rental')
# (1, u'Renovations')
# (1, u'Remove')
# (1, u'Remember')
# (1, u'Relationship')
# (1, u'Regardless')
# (1, u'Reduce')
# (1, u'Recreational')
# (1, u'Puppies')
# (1, u'Proper')
# (1, u'Priority')
# (1, u'Press')
# (1, u'Prattville')
# (1, u'Plan')
# (1, u'Pay')
# (1, u'Parks')
# (1, u'Parking')
# (1, u'Paint')
# (1, u'Packing')
# (1, u'PR')
# (1, u'Owners')
# (1, u'Oven')
# (1, u'Orange')
# (1, u'On')
# (1, u'O')
# (1, u'November')
# (1, u'Nothing')
# (1, u'Normally')
# (1, u'News')
# (1, u'Neighbors')
# (1, u'Neglecting')
# (1, u'Neck')
# (1, u'National')
# (1, u'Morning')
# (1, u'Million')
# (1, u'Millennials')
# (1, u'Melanie')
# (1, u'Meghan')
# (1, u'Meet')
# (1, u'Marlin')
# (1, u'Making')
# (1, u'Major')
# (1, u'MASH')
# (1, u'Look')
# (1, u'Lock')
# (1, u'Like')
# (1, u'Lift')
# (1, u'Lender')
# (1, u'LOT')
# (1, u'L')
# (1, u'Knowing')
# (1, u'Know')
# (1, u'Klingenberg')
# (1, u'Kishk')
# (1, u'Key')
# (1, u'Judge')
# (1, u'Journal')
# (1, u'Josh')
# (1, u'Joseph')
# (1, u'Jason')
# (1, u'Island')
# (1, u'Inspector')
# (1, u'Imagine')
# (1, u'Ignore')
# (1, u'I')
# (1, u'House')
# (1, u'Hiring')
# (1, u'Her')
# (1, u'Heath')
# (1, u'Has')
# (1, u'Guide')
# (1, u'Group')
# (1, u'Gravel')
# (1, u'Grab')
# (1, u'Get')
# (1, u'G')
# (1, u'Future')
# (1, u'Fun')
# (1, u'Front')
# (1, u'Forgetting')
# (1, u'Following')
# (1, u'Follow')
# (1, u'Focus')
# (1, u'Floor')
# (1, u'Fite')
# (1, u'First')
# (1, u'Filing')
# (1, u'Figure')
# (1, u'Faucets')
# (1, u'Father')
# (1, u'Family')
# (1, u'Explore')
# (1, u'Expect')
# (1, u'Examine')
# (1, u'Everything')
# (1, u'Even')
# (1, u'Escrow')
# (1, u'Electrical')
# (1, u'Either')
# (1, u'Drive')
# (1, u'Double')
# (1, u'Door')
# (1, u'Dont')
# (1, u'Dollar')
# (1, u'Disease')
# (1, u'Develop')
# (1, u'Detached')
# (1, u'Depending')
# (1, u'Deerfield')
# (1, u'Deep')
# (1, u'Deciding')
# (1, u'Daleville')
# (1, u'DIY')
# (1, u'Crescent')
# (1, u'Credit')
# (1, u'Cracks')
# (1, u'County')
# (1, u'Cook')
# (1, u'Control')
# (1, u'Condo')
# (1, u'Conclusion')
# (1, u'Compare')
# (1, u'Communities')
# (1, u'Communications')
# (1, u'Combat')
# (1, u'Collin')
# (1, u'Click')
# (1, u'Cleaning')
# (1, u'Cityside')
# (1, u'City')
# (1, u'Christen')
# (1, u'China')
# (1, u'Checklist')
# (1, u'Center')
# (1, u'Cara')
# (1, u'Campaign')
# (1, u'Call')
# (1, u'Calculator')
# (1, u'Cabinet')
# (1, u'COO')
# (1, u'CEO')
# (1, u'CDC')
# (1, u'C21_Jan_B2_Infographic_v2')
# (1, u'Buyers')
# (1, u'Bray')
# (1, u'Brand')
# (1, u'Boynton')
# (1, u'Boston')
# (1, u'Blue')
# (1, u'Block')
# (1, u'Below')
# (1, u'Becky')
# (1, u'Bathroom')
# (1, u'Basement')
# (1, u'Awards')
# (1, u'Avoid')
# (1, u'Attractive')
# (1, u'Attorney')
# (1, u'Attic')
# (1, u'At')
# (1, u'Associate')
# (1, u'Aside')
# (1, u'April')
# (1, u'Appraiser')
# (1, u'Appliances')
# (1, u'Apartment')
# (1, u'Another')
# (1, u'Amenities')
# (1, u'Altman')
# (1, u'Alabama')
# (1, u'Aim')
# (1, u'Agent')
# (1, u'Affiliated')
# (1, u'Add')
# (1, u'AKA')
# (1, u'<em>')
# (1, u'</em>')
# (1, u'97')
# (1, u'9')
# (1, u'8\\')
# (1, u'76')
# (1, u'736w')
# (1, u'736')
# (1, u'70')
# (1, u'7')
# (1, u'462w')
# (1, u'25')
# (1, u'195w')
# (1, u'17')
# (1, u'1630')
# (1, u'16')
# (1, u'14')
# (1, u'135w')
# (1, u'13')
# (1, u'12')
# (1, u'107')
# (1, u'10180')
# (1, u'100vw')

# %%
final_word = []#find the 50 most common words
aux = tuple(aux)
final_word = aux[13]+aux[25]+aux[65]+aux[71]+aux[75]+aux[83]+aux[84]+aux[101]+aux[109:115]+aux[129]+aux[131]+aux[135]+aux[137]+aux[139:145]+aux[180:190]+aux[469:473]

# %%
from os import path
from wordcloud import WordCloud

#d = path.dirname(__file__)
#e = final_word
# Read the whole text.
#text = open(path.join(d, 'constitution.txt')).read()
#e = str(e)
#e = ['a','b','e','apple','apple']
e = str(final_word)
# Generate a word cloud image
wordcloud = WordCloud().generate(e)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(e)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
